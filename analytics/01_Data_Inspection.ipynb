# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("../dataset/raw/placement_data.csv")
print(data.sample(5))
print(data.shape)
print(data.columns)
print(data.head(10))
# Out:
#       branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 5223     ECE       Tier-2  6.31         0            3.4        5.8
# 29835    CSE       Tier-1  8.18         0            7.4        5.4
# 21519     IT       Tier-2  7.16         0            8.8        5.2
# 13811    CSE       Tier-3  7.38         2            3.3        8.2
# 24952    CSE       Tier-3  6.12         0            4.9        5.1
#
#        aptitude_score  communication_skills  ml_knowledge  system_design  \
# 5223             60.7                   3.3           7.1            3.0
# 29835           100.0                   6.8           5.9            4.7
# 21519            58.5                   7.4           3.9            0.7
# 13811            73.0                   5.8           4.8            4.7
# 24952            64.3                   4.2           4.1            3.5
#
#        internships  projects_count  certifications  hackathons  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   branch                     99999 non-null  str
#  1   college_tier               99999 non-null  str
#  2   cgpa                       99999 non-null  float64
#  3   backlogs                   99999 non-null  int64
#  4   coding_skills              99999 non-null  float64
#  5   dsa_score                  99999 non-null  float64
#  6   aptitude_score             99999 non-null  float64
#  7   communication_skills       99999 non-null  float64
#  8   ml_knowledge               99999 non-null  float64
#  9   system_design              99999 non-null  float64
#  10  internships                99999 non-null  int64
#  11  projects_count             99999 non-null  int64
#  12  certifications             99999 non-null  int64
# ...

# %%
print("Rows and Columns:", data.shape)
print("\nColumn Names:")
print(data.columns.tolist())
print("\nDataset Info:")
data.info()
# Out:
# Rows and Columns: (99999, 18)
#
# Column Names:
# ['branch', 'college_tier', 'cgpa', 'backlogs', 'coding_skills', 'dsa_score', 'aptitude_score', 'communication_skills', 'ml_knowledge', 'system_design', 'internships', 'projects_count', 'certifications', 'hackathons', 'open_source_contributions', 'extracurriculars', 'placement_status', 'salary_package_lpa']
#
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   branch                     99999 non-null  str
#  1   college_tier               99999 non-null  str
#  2   cgpa                       99999 non-null  float64
#  3   backlogs                   99999 non-null  int64
#  4   coding_skills              99999 non-null  float64
#  5   dsa_score                  99999 non-null  float64
#  6   aptitude_score             99999 non-null  float64
# ...

# %%
data.describe()
data.nunique()
# Out:
# branch                          7
# college_tier                    3
# cgpa                          597
# backlogs                        4
# coding_skills                  91
# dsa_score                      91
# aptitude_score                765
# communication_skills           91
# ml_knowledge                  101
# system_design                 101
# internships                     4
# projects_count                  6
# certifications                  5
# hackathons                      4
# open_source_contributions       3
# extracurriculars                4
# placement_status                2
# salary_package_lpa           1654
# dtype: int64

# %%
missing_values = data.isnull().sum()
print("Missing values in each column:")
print(missing_values)
print("\nTotal missing values:", missing_values.sum())
# Out:
# Missing values in each column:
# branch                           0
# college_tier                     0
# cgpa                             0
# backlogs                         0
# coding_skills                    0
# dsa_score                        0
# aptitude_score                   0
# communication_skills             0
# ml_knowledge                     0
# system_design                    0
# internships                      0
# projects_count                   0
# certifications                   0
# hackathons                       0
# open_source_contributions        0
# extracurriculars                 0
# placement_status                 0
# salary_package_lpa           31525
# dtype: int64
#
# Total missing values: 31525

# %%
count_dublicate = data.duplicated().sum()
count_dublicate
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#                cgpa      backlogs  coding_skills     dsa_score  \
# count  99999.000000  99999.000000   99999.000000  99999.000000
# mean       7.206383      0.547015       5.995179      5.500713
# std        0.925239      0.862729       1.496276      1.781970
# min        4.000000      0.000000       1.000000      1.000000
# 25%        6.580000      0.000000       5.000000      4.300000
# 50%        7.210000      0.000000       6.000000      5.500000
# 75%        7.830000      1.000000       7.000000      6.700000
# max       10.000000      3.000000      10.000000     10.000000
#
#        aptitude_score  communication_skills  ml_knowledge  system_design  \
# count    99999.000000          99999.000000  99999.000000   99999.000000
# mean        64.990516              5.990617      4.508740       4.008216
# std         11.990952              1.496559      1.968285       1.778413
# min         20.000000              1.000000      0.000000       0.000000
# ...

# %%
print("branch:-",data["branch"].value_counts())
print("placement Status:-",data["placement_status"].value_counts())
print("Collage tier:-",data["college_tier"].value_counts())
# Out:
# branch:- branch
# CSE         25046
# IT          16065
# ECE         14938
# EE          12092
# ME          12008
# CE          10024
# Chemical     9826
# Name: count, dtype: int64
# placement Status:- placement_status
# 1    68474
# 0    31525
# Name: count, dtype: int64
# Collage tier:- college_tier
# Tier-3    45222
# Tier-2    39910
# Tier-1    14867
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['branch', 'college_tier', 'cgpa', 'backlogs', 'coding_skills',
#        'dsa_score', 'aptitude_score', 'communication_skills', 'ml_knowledge',
#        'system_design', 'internships', 'projects_count', 'certifications',
#        'hackathons', 'open_source_contributions', 'extracurriculars',
#        'placement_status', 'salary_package_lpa'],
#       dtype='str')

# %%
data.nunique()
# Out:
# branch                          7
# college_tier                    3
# cgpa                          597
# backlogs                        4
# coding_skills                  91
# dsa_score                      91
# aptitude_score                765
# communication_skills           91
# ml_knowledge                  101
# system_design                 101
# internships                     4
# projects_count                  6
# certifications                  5
# hackathons                      4
# open_source_contributions       3
# extracurriculars                4
# placement_status                2
# salary_package_lpa           1654
# dtype: int64

# %%
numbric_data = data.select_dtypes(include="number")
print("Numbric data sets:-\n")
numbric_data.agg(['max','min'])
# Out:
# Numbric data sets:-
#      cgpa  backlogs  coding_skills  dsa_score  aptitude_score  \
# max  10.0         3           10.0       10.0           100.0
# min   4.0         0            1.0        1.0            20.0
#
#      communication_skills  ml_knowledge  system_design  internships  \
# max                  10.0          10.0           10.0            3
# min                   1.0           0.0            0.0            0
#
#      projects_count  certifications  hackathons  open_source_contributions  \
# max               5               4           3                          2
# min               0               0           0                          0
#
#      extracurriculars  placement_status  salary_package_lpa
# max                 3                 1               28.33
# min                 0                 0                6.88

# %%
print(data.describe())
print(data.nunique())
print(data.value_counts())
# Out:
#                cgpa      backlogs  coding_skills     dsa_score  \
# count  99999.000000  99999.000000   99999.000000  99999.000000
# mean       7.206383      0.547015       5.995179      5.500713
# std        0.925239      0.862729       1.496276      1.781970
# min        4.000000      0.000000       1.000000      1.000000
# 25%        6.580000      0.000000       5.000000      4.300000
# 50%        7.210000      0.000000       6.000000      5.500000
# 75%        7.830000      1.000000       7.000000      6.700000
# max       10.000000      3.000000      10.000000     10.000000
#
#        aptitude_score  communication_skills  ml_knowledge  system_design  \
# count    99999.000000          99999.000000  99999.000000   99999.000000
# mean        64.990516              5.990617      4.508740       4.008216
# std         11.990952              1.496559      1.968285       1.778413
# min         20.000000              1.000000      0.000000       0.000000
# ...

# %%
data.groupby("placement_status")["salary_package_lpa"].apply(lambda x: x.isna().sum())
# Out:
# placement_status
# 0    31525
# 1        0
# Name: salary_package_lpa, dtype: int64

# %%
# Count missing values for every column
missing_counts = data.isna().sum()

# Filter to only display columns that actually have missing values
missing_counts[missing_counts > 0]
# Out:
# salary_package_lpa    31525
# dtype: int64
