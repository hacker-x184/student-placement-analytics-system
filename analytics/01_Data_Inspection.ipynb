# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("../dataset/raw/placement_data.csv")
print(data.sample(5))
print(data.shape)
print(data.columns)
print(data.head(10))
# Out:
#       branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 62874     EE       Tier-3  4.85         0            7.5        4.4
# 33142     EE       Tier-3  7.28         1            5.4        3.5
# 14038     CE       Tier-1  7.81         0            6.2        4.2
# 6555      EE       Tier-1  9.62         1            4.8        3.2
# 47681     IT       Tier-3  5.66         1            2.6        6.5
#
#        aptitude_score  communication_skills  ml_knowledge  system_design  \
# 62874            62.5                   9.6           3.8            3.7
# 33142            58.0                   8.3           0.0            4.9
# 14038            53.2                   5.9           3.2            5.9
# 6555             79.6                   7.2           6.6            0.0
# 47681            60.1                   5.3           3.8            3.2
#
#        internships  projects_count  certifications  hackathons  \
# ...
