# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("../dataset/raw/placement_data.csv")
print(data.sample(5))
print(data.shape)
print(data.columns)
print(data.head(10))
# Out:
#          branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 44800  Chemical       Tier-3  6.84         0            5.1        4.3
# 25840        IT       Tier-2  6.07         3            6.7        5.4
# 11210       CSE       Tier-3  7.89         0            5.7        4.7
# 16884        CE       Tier-3  5.74         0            7.1        5.5
# 88573  Chemical       Tier-2  7.81         0            5.6        3.9
#
#        aptitude_score  communication_skills  ml_knowledge  system_design  \
# 44800            66.9                   7.9           3.8            1.2
# 25840            74.2                   6.2           3.6            2.1
# 11210            69.6                   6.4           5.0            4.5
# 16884            49.5                   5.5           6.1            6.0
# 88573            55.0                   5.6           0.1            2.7
#
#        internships  projects_count  certifications  hackathons  \
# ...
